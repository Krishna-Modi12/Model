# %% [markdown]
# # Face Shape AI — Google Colab Training 🚀
# This notebook allows you to train the Face Shape Classification model using Colab's free/pro GPUs.
#
# ### 1. Connect to GPU
# Go to **Runtime** > **Change runtime type** > Select **T4 GPU** (or better).
#
# ### 2. Mount Google Drive
# Upload your project folder (`Model/`) to your Google Drive first.

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# ### 3. Navigate to Project & Install Dependencies

# %%
import os
# Update this path to where you uploaded the 'Model' folder in your Drive
PROJECT_PATH = '/content/drive/MyDrive/Model'
os.chdir(PROJECT_PATH)

# !pip install -r requirements.txt
# !pip install pytorch-lightning timm albumentations loguru mediapipe

# %% [markdown]
# ### 4. Run Training
# You can run any training script here (e.g., Phase 4 ConvNeXt).

# %%
# !python phase4_convnext.py

# %% [markdown]
# ### 5. (Optional) Run Gradio Demo in Colab

# %%
# !python app.py --share
